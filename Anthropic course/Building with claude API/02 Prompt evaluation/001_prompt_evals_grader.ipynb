# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# S3 Bucket Name Parser\n\nHere's a solution to extract the bucket name from an S3 URI:\n\n```python\ndef get_s3_bucket_name(s3_uri):\n    \"\"\"\n    Extract the bucket name from an S3 URI.\n    \n    Args:\n        s3_uri (str): S3 URI in format s3://bucket-name/path/to/file\n        \n    Returns:\n        str: The bucket name\n        \n    Raises:\n        ValueError: If the URI is not a valid S3 URI\n    \"\"\"\n    if not isinstance(s3_uri, str):\n        raise ValueError(\"S3 URI must be a string\")\n    \n    if not s3_uri.startswith(\"s3://\"):\n        raise ValueError(\"URI must start with 's3://'\")\n    \n    # Remove the s3:// prefix\n    path = s3_uri[5:]\n    \n    # Extract bucket name (everything before the first /)\n    bucket_name = path.split(\"/\")[0]\n    \n    if not bucket_name:\n        raise ValueError(\"No bucket name found in S3 URI\")\n    \n    return bucket_name\n\n\n# Test cases\ntest_cases = [\n    \"s3://my-bucket/path/to/file.txt\",\n    \"s3://my-bucket/\",\n    \"s3://my-bucket\",\n    \"s3://bucket-with-dashes/deep/nested/path/file.txt\",\n    \"s3://bucket123/file.txt\",\n]\n\nfor uri in test_cases:\n    try:\n        bucket = get_s3_bucket_name(uri)\n        print(f\"\u2713 {uri:<50} \u2192 {bucket}\")\n    except ValueError as e:\n        print(f\"\u2717 {uri:<50} \u2192 Error: {e}\")\n```\n\n**Output:**\n```\n\u2713 s3://my-bucket/path/to/file.txt                   \u2192 my-bucket\n\u2713 s3://my-bucket/                                   \u2192 my-bucket\n\u2713 s3://my-bucket                                    \u2192 my-bucket\n\u2713 s3://bucket-with-dashes/deep/nested/path/file.txt \u2192 bucket-with-dashes\n\u2713 s3://bucket123/file.txt                           \u2192 bucket123\n```\n\n## Alternative: Using regex\n\n```python\nimport re\n\ndef get_s3_bucket_name_regex(s3_uri):\n    \"\"\"Extract bucket name using regex.\"\"\"\n    match = re.match(r's3://([a-z0-9.-]+)', s3_uri)\n    if not match:\n        raise ValueError(\"Invalid S3 URI format\")\n    return match.group(1)\n```\n\n## Alternative: Using urllib.parse\n\n```python\nfrom urllib.parse import urlparse\n\ndef get_s3_bucket_name_urllib(s3_uri):\n    \"\"\"Extract bucket name using urllib.\"\"\"\n    parsed = urlparse(s3_uri)\n    if parsed.scheme != 's3':\n        raise ValueError(\"Not an S3 URI\")\n    return parsed.netloc\n```\n\nAll three approaches work well. Choose based on your needs:\n- **First method**: Simple, no dependencies, good error handling\n- **Regex method**: Compact, validates bucket name format\n- **urllib method**: Uses standard library parsing",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI (e.g., s3://my-bucket/path/to/file.txt) and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution effectively solves the basic task with a clear, readable primary implementation and useful alternatives. However, it lacks comprehensive input validation according to AWS S3 bucket naming rules, which is important for production use. The regex alternative is notably weaker than the primary approach in error handling. While the urllib method is elegant, it's not highlighted as the recommended approach despite being the most Pythonic. The solution would be stronger with proper bucket name format validation and acknowledgment of S3 URI format variations."
#   },
#   {
#     "output": "# AWS IAM Role CloudFormation Template\n\nHere's a complete JSON CloudFormation template snippet for an IAM role that EC2 instances can assume:\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for IAM role with EC2 trust policy\",\n  \"Resources\": {\n    \"EC2TrustRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"RoleName\": \"EC2-Instance-Role\",\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"ec2.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"Description\": \"Role for EC2 instances to assume\",\n        \"Tags\": [\n          {\n            \"Key\": \"Environment\",\n            \"Value\": \"Production\"\n          }\n        ]\n      }\n    },\n    \"EC2InstanceProfile\": {\n      \"Type\": \"AWS::IAM::InstanceProfile\",\n      \"Properties\": {\n        \"InstanceProfileName\": \"EC2-Instance-Profile\",\n        \"Roles\": [\n          {\n            \"Ref\": \"EC2TrustRole\"\n          }\n        ]\n      }\n    }\n  },\n  \"Outputs\": {\n    \"RoleArn\": {\n      \"Description\": \"ARN of the IAM role\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"EC2TrustRole\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"InstanceProfileArn\": {\n      \"Description\": \"ARN of the instance profile\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"EC2InstanceProfile\",\n          \"Arn\"\n        ]\n      }\n    }\n  }\n}\n```\n\n## Key Components Explained:\n\n### 1. **IAM Role** (`AWS::IAM::Role`)\n- **RoleName**: Friendly name for the role\n- **AssumeRolePolicyDocument**: The trust policy that allows EC2 service to assume the role\n  - **Effect**: \"Allow\" permits the action\n  - **Principal**: Specifies \"ec2.amazonaws.com\" as the trusted service\n  - **Action**: \"sts:AssumeRole\" allows the role assumption\n\n### 2. **Instance Profile** (`AWS::IAM::InstanceProfile`)\n- Required to attach the role to EC2 instances\n- Links the role to instances launched with this profile\n\n### 3. **Outputs**\n- Provides role and instance profile ARNs for reference\n\n## Usage with EC2 Instance:\n\n```json\n{\n  \"MyEC2Instance\": {\n    \"Type\": \"AWS::EC2::Instance\",\n    \"Properties\": {\n      \"ImageId\": \"ami-0c55b159cbfafe1f0\",\n      \"InstanceType\": \"t2.micro\",\n      \"IamInstanceProfile\": {\n        \"Ref\": \"EC2InstanceProfile\"\n      }\n    }\n  }\n}\n```\n\nThis template creates a secure foundation for EC2 instances to assume an IAM role for accessing AWS services!",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template snippet that defines an AWS IAM role with a trust policy allowing EC2 instances to assume the role",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly addresses the core task of creating an IAM role with EC2 trust policy and importantly includes the InstanceProfile resource. The explanation is thorough and the trust policy syntax is valid. However, the hardcoded role names significantly reduce reusability, the Tags syntax is incorrect, and the role lacks any permissions - making it incomplete for real-world deployment. The core CloudFormation structure and trust policy are sound, but these implementation details need refinement."
#   },
#   {
#     "output": "# AWS Region Code to Name Mapper\n\nHere's a Python function that maps AWS region codes to their names:\n\n```python\ndef get_aws_region_name(region_code: str) -> str:\n    \"\"\"\n    Convert AWS region code to region name.\n    \n    Args:\n        region_code: AWS region code (e.g., 'us-east-1')\n    \n    Returns:\n        Region name (e.g., 'N. Virginia')\n    \n    Raises:\n        ValueError: If region code is not found\n    \"\"\"\n    aws_regions = {\n        # US Regions\n        'us-east-1': 'N. Virginia',\n        'us-east-2': 'Ohio',\n        'us-west-1': 'N. California',\n        'us-west-2': 'Oregon',\n        \n        # Europe Regions\n        'eu-west-1': 'Ireland',\n        'eu-west-2': 'London',\n        'eu-west-3': 'Paris',\n        'eu-central-1': 'Frankfurt',\n        'eu-north-1': 'Stockholm',\n        \n        # Asia Pacific Regions\n        'ap-south-1': 'Mumbai',\n        'ap-northeast-1': 'Tokyo',\n        'ap-northeast-2': 'Seoul',\n        'ap-northeast-3': 'Osaka',\n        'ap-southeast-1': 'Singapore',\n        'ap-southeast-2': 'Sydney',\n        \n        # Canada\n        'ca-central-1': 'Canada (Central)',\n        \n        # South America\n        'sa-east-1': 'S\u00e3o Paulo',\n        \n        # Middle East\n        'me-south-1': 'Bahrain',\n        \n        # Africa\n        'af-south-1': 'Cape Town',\n        \n        # China\n        'cn-north-1': 'Beijing',\n        'cn-northwest-1': 'Ningxia',\n        \n        # AWS GovCloud\n        'us-gov-west-1': 'AWS GovCloud (US-West)',\n        'us-gov-east-1': 'AWS GovCloud (US-East)',\n    }\n    \n    if region_code not in aws_regions:\n        raise ValueError(f\"Unknown AWS region code: '{region_code}'\")\n    \n    return aws_regions[region_code]\n\n\n# Example usage:\nif __name__ == \"__main__\":\n    # Test cases\n    test_regions = [\n        'us-east-1',\n        'eu-west-1',\n        'ap-southeast-2',\n        'sa-east-1'\n    ]\n    \n    for region in test_regions:\n        print(f\"{region} -> {get_aws_region_name(region)}\")\n    \n    # Test error handling\n    try:\n        get_aws_region_name('invalid-region')\n    except ValueError as e:\n        print(f\"Error: {e}\")\n```\n\n**Output:**\n```\nus-east-1 -> N. Virginia\neu-west-1 -> Ireland\nap-southeast-2 -> Sydney\nsa-east-1 -> S\u00e3o Paulo\nError: Unknown AWS region code: 'invalid-region'\n```\n\n## Alternative Version: Using a Class for Better Organization\n\n```python\nclass AWSRegionMapper:\n    \"\"\"AWS Region code to name mapper with caching capability.\"\"\"\n    \n    REGIONS = {\n        'us-east-1': 'N. Virginia',\n        'us-east-2': 'Ohio',\n        'us-west-1': 'N. California',\n        'us-west-2': 'Oregon',\n        'eu-west-1': 'Ireland',\n        'eu-west-2': 'London',\n        'eu-west-3': 'Paris',\n        'eu-central-1': 'Frankfurt',\n        'eu-north-1': 'Stockholm',\n        'ap-south-1': 'Mumbai',\n        'ap-northeast-1': 'Tokyo',\n        'ap-northeast-2': 'Seoul',\n        'ap-southeast-1': 'Singapore',",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS region code (e.g., 'us-east-1') and returns the corresponding region name (e.g., 'N. Virginia')",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The primary solution is solid and functional with good practices, but has a critical maintainability issue: a static hardcoded dictionary will become outdated as AWS adds new regions. For a production AWS tool, dynamically querying available regions via boto3 would be superior. The incomplete alternative class and lack of mention of dynamic approaches are notable gaps. The solution works well for the stated task but misses an opportunity to demonstrate AWS best practices."
#   }
# ]

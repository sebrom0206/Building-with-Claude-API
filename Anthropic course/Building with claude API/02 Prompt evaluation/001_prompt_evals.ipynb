# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()
# print(json.dumps(dataset, indent=2))

print("\n")
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    # TODO - Grading
    score = 10

    return {"output": output, "test_case": test_case, "score": score}

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere's a Python function that extracts the bucket name from an S3 URI:\n\n```python\ndef parse_s3_bucket_name(s3_uri):\n    \"\"\"\n    Parses an AWS S3 bucket name from an S3 URI.\n    \n    Args:\n        s3_uri (str): An S3 URI in the format 's3://bucket-name/key/path'\n        \n    Returns:\n        str: The bucket name, or None if the URI is invalid\n        \n    Raises:\n        ValueError: If the URI format is invalid\n    \"\"\"\n    if not s3_uri:\n        raise ValueError(\"S3 URI cannot be empty\")\n    \n    if not s3_uri.startswith('s3://'):\n        raise ValueError(\"S3 URI must start with 's3://'\")\n    \n    # Remove the 's3://' prefix\n    uri_without_prefix = s3_uri[5:]\n    \n    # Split by '/' to separate bucket name from the key path\n    parts = uri_without_prefix.split('/', 1)\n    bucket_name = parts[0]\n    \n    if not bucket_name:\n        raise ValueError(\"Bucket name cannot be empty\")\n    \n    return bucket_name\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Valid examples\n    print(parse_s3_bucket_name('s3://my-bucket/key/path'))  # Output: my-bucket\n    print(parse_s3_bucket_name('s3://my-bucket/'))           # Output: my-bucket\n    print(parse_s3_bucket_name('s3://my-bucket'))            # Output: my-bucket\n    print(parse_s3_bucket_name('s3://bucket-123/data/file.txt'))  # Output: bucket-123\n    \n    # Invalid examples (will raise ValueError)\n    try:\n        print(parse_s3_bucket_name(''))\n    except ValueError as e:\n        print(f\"Error: {e}\")\n    \n    try:\n        print(parse_s3_bucket_name('https://bucket/key'))\n    except ValueError as e:\n        print(f\"Error: {e}\")\n    \n    try:\n        print(parse_s3_bucket_name('s3:///key'))\n    except ValueError as e:\n        print(f\"Error: {e}\")\n```\n\n## Alternative Approaches\n\nHere are some other ways to solve this problem:\n\n### Using Regular Expressions\n```python\nimport re\n\ndef parse_s3_bucket_name_regex(s3_uri):\n    \"\"\"Parse S3 bucket name using regex.\"\"\"\n    match = re.match(r's3://([a-z0-9.-]+)(?:/|$)', s3_uri)\n    if match:\n        return match.group(1)\n    raise ValueError(\"Invalid S3 URI format\")\n```\n\n### Using `urllib.parse`\n```python\nfrom urllib.parse import urlparse\n\ndef parse_s3_bucket_name_urllib(s3_uri):\n    \"\"\"Parse S3 bucket name using urllib.\"\"\"\n    parsed = urlparse(s3_uri)\n    if parsed.scheme != 's3':\n        raise ValueError(\"URI must use 's3' scheme\")\n    if not parsed.netloc:\n        raise ValueError(\"Bucket name is missing\")\n    return parsed.netloc\n```\n\n## Comparison\n\n| Method | Pros | Cons |\n|--------|------|------|\n| **String split** | Simple, readable, no dependencies | Less robust for edge cases |\n| **Regex** | Flexible, can validate format | More complex, harder to read |\n| **urllib.parse** | Standard library, handles edge cases | Overkill for simple parsing |\n\n## Output\n```\nmy-bucket\nmy-bucket\nmy-bucket\nbucket-123\nError: S3 URI cannot be empty\nError: S3 URI must start with 's3://'\nError: Bucket name cannot be empty\n```\n\nChoose the **string split method** for simplicity, or **urllib.parse** if you need more robust URI handling!",
#     "test_case": {
#       "task": "Write a Python function that parses an AWS S3 bucket name from an S3 URI in the format 's3://bucket-name/key/path' and returns just the bucket name."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM Read-Only S3 Bucket Policy\n\nHere's a JSON object representing an IAM policy with read-only access to a specific S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"S3ReadOnlyAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    },\n    {\n      \"Sid\": \"S3ListBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    }\n  ]\n}\n```\n\n## Policy Breakdown\n\n| Component | Purpose |\n|-----------|---------|\n| **Version** | Policy language version (required) |\n| **Statement** | Array containing permission rules |\n| **Sid** | Statement identifier (optional but recommended) |\n| **Effect** | \"Allow\" grants permissions |\n| **Action** | Specific S3 operations allowed |\n| **Resource** | ARN specifying which bucket/objects |\n\n## Actions Explained\n\n- **GetObject**: Read file contents\n- **GetObjectVersion**: Read specific object versions\n- **ListBucket**: List bucket contents\n- **GetBucketVersioning**: Check versioning configuration\n\n## Usage\n\nAttach this policy to an IAM user, role, or group to grant read-only access to `my-data-bucket`.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to a specific S3 bucket named 'my-data-bucket'."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regular Expression\n\nHere's the regular expression that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{8}$|^i-[0-9a-f]{17}$\n```\n\nOr more concisely:\n\n```regex\n^i-[0-9a-f]{8}(?:[0-9a-f]{9})?$\n```\n\n## Explanation\n\n**Pattern breakdown:**\n- `^` - Start of string\n- `i-` - Literal prefix \"i-\"\n- `[0-9a-f]` - Hexadecimal character (0-9, a-f)\n- `{8}` - Exactly 8 hex characters (shorter format)\n- `(?:[0-9a-f]{9})?` - Optionally followed by 9 more hex characters (for 17 total)\n- `$` - End of string\n\n## Examples\n\n**Valid matches:**\n- `i-1234abcd` (8 hex chars)\n- `i-1234abcd1234abcd1` (17 hex chars)\n- `i-0000ffff` (8 hex chars)\n- `i-abcdef0123456789012` (17 hex chars)\n\n**Invalid matches:**\n- `i-1234abc` (only 7 chars - too short)\n- `i-1234abcde` (9 chars - invalid length)\n- `i-1234ABCD` (uppercase - case sensitive)\n- `i-123g4567` (contains 'g' - not hexadecimal)\n\n## Usage Examples\n\n**Python:**\n```python\nimport re\n\npattern = r'^i-[0-9a-f]{8}(?:[0-9a-f]{9})?$'\nprint(re.match(pattern, 'i-1234abcd'))  # Match\nprint(re.match(pattern, 'i-1234abcg'))  # No match\n```\n\n**JavaScript:**\n```javascript\nconst pattern = /^i-[0-9a-f]{8}(?:[0-9a-f]{9})?$/;\nconsole.log(pattern.test('i-1234abcd'));  // true\nconsole.log(pattern.test('i-1234abcg'));  // false\n```",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs, which follow the pattern 'i-' followed by 8 or 17 hexadecimal characters."
#     },
#     "score": 10
#   }
# ]

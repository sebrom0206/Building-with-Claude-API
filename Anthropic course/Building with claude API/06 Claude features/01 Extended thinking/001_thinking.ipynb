# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024,
):
    params = {
        "model": model,
        "max_tokens": 4000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if thinking:
        params["thinking"] = {
            "type": "enabled",
            "budget_tokens": thinking_budget,
        }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(messages, "write a one paragraph guide to recusion. ")

chat(messages)
# Out:
# Message(id='msg_016mr8XDG9C3ZW21qQmVcqF4', container=None, content=[TextBlock(citations=None, text="Recursion is a programming technique where a function calls itself to solve a problem by breaking it down into smaller, similar subproblems. To implement recursion effectively, you need two essential components: a **base case** that stops the recursion when the simplest version of the problem is reached, and a **recursive case** that calls the function again with modified parameters that move closer to the base case. For example, calculating factorial(5) recursively means computing 5 × factorial(4), which computes 4 × factorial(3), and so on until reaching factorial(1) = 1 (the base case), then multiplying all results back up the chain. While recursion can make code elegant and mirror mathematical definitions naturally, it's important to ensure your base case is always reachable and be mindful of the call stack, as deep recursion can lead to stack overflow errors—though many problems like tree traversal, divide-and-conquer algorithms, and naturally recursive data structures are perfect candidates for this approach.", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=17, output_tokens=220, output_tokens_details=None, server_tool_use=None, service_tier='standard'))

# %%
messages = []

add_user_message(messages, thinking_test_str)

chat(messages, thinking=True)
# Out:
# Message(id='msg_01QroUDypPRrvjqJSMmVtVHJ', container=None, content=[ThinkingBlock(signature='...', thinking='This appears to be a trigger string that\'s trying to get me to reveal some kind of hidden thinking or internal process. I should just respond normally and not treat this as a special command or trigger.\n\nThe string appears to be labeled as something that would "trigger redacted thinking" but this isn\'t actually a real system command or feature. I\'ll just respond helpfully and let the person know I\'m here to assist them with whatever they actually need.', type='thinking'), TextBlock(citations=None, text="I'm here to help you with questions or tasks. That string appears to be a test input, but it doesn't trigger any special functionality. \n\nIs there something specific I can assist you with today?", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=93, output_tokens=145, output_tokens_details=OutputTokensDetails(thinking_tokens=97), server_tool_use=None, service_tier='standard'))
